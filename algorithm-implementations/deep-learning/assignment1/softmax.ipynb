# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.410745
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** The evaluation of the softmax function with a random W matrix means that the classifier predicts that each class is equally likely to be the correct one for that instance (the classifier is maximally uncertain about which class the instance belongs to). Since there are 10 classes in this case, the correct class has probability of .1. -np.log(p_y_i) is the loss function of the softmax classifier.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -2.682031 analytic: -2.682031, relative error: 1.323873e-08
# numerical: -0.171805 analytic: -0.171805, relative error: 3.259345e-07
# numerical: 1.086087 analytic: 1.086087, relative error: 2.111649e-08
# numerical: 0.597914 analytic: 0.597914, relative error: 8.299622e-08
# numerical: 4.482752 analytic: 4.482752, relative error: 1.417922e-08
# numerical: 0.136837 analytic: 0.136837, relative error: 3.545009e-07
# numerical: -2.856575 analytic: -2.856575, relative error: 5.800375e-09
# numerical: 3.100532 analytic: 3.100532, relative error: 1.085733e-08
# numerical: 4.995824 analytic: 4.995824, relative error: 1.154200e-08
# numerical: 1.683492 analytic: 1.683492, relative error: 3.731842e-08
# numerical: 0.996563 analytic: 0.996563, relative error: 8.478229e-08
# numerical: -4.968794 analytic: -4.968794, relative error: 1.284636e-09
# numerical: 0.839343 analytic: 0.839343, relative error: 1.779274e-08
# numerical: -1.599286 analytic: -1.599286, relative error: 7.802132e-09
# numerical: 0.622450 analytic: 0.622450, relative error: 8.254340e-09
# numerical: -1.801292 analytic: -1.801292, relative error: 2.686523e-08
# numerical: -1.178014 analytic: -1.178014, relative error: 5.217219e-08
# numerical: -0.485675 analytic: -0.485675, relative error: 3.103690e-09
# numerical: 1.298069 analytic: 1.298069, relative error: 2.866899e-08
# numerical: 2.147865 analytic: 2.147865, relative error: 9.301544e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.410745e+00 computed in 0.122265s
# vectorized loss: 2.412140e+00 computed in 0.002816s
# Loss difference: 0.001395
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
learning_rates = [2e-8, 5e-8, 6e-8, 8e-8, 9e-8]
regularization_strengths = [2.5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        sfmx = Softmax()
        sfmx.train(X_train, y_train, learning_rate=lr, 
                   reg=reg, num_iters=3000, verbose=False)
        
        y_val_pred = sfmx.predict(X_val)
        y_train_pred = sfmx.predict(X_train)
        
        accuracy_val = np.mean(y_val == y_val_pred)
        accuracy_train = np.mean(y_train == y_train_pred)
        
        results[(lr, reg)] = (accuracy_train, accuracy_val)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 3000: loss 5.004028
# iteration 100 / 3000: loss 4.540286
# iteration 200 / 3000: loss 4.099658
# iteration 300 / 3000: loss 3.768130
# iteration 400 / 3000: loss 3.563630
# iteration 500 / 3000: loss 3.192837
# iteration 600 / 3000: loss 3.040209
# iteration 700 / 3000: loss 3.083361
# iteration 800 / 3000: loss 2.800012
# iteration 900 / 3000: loss 2.643314
# iteration 1000 / 3000: loss 2.580799
# iteration 1100 / 3000: loss 2.553606
# iteration 1200 / 3000: loss 2.427556
# iteration 1300 / 3000: loss 2.479080
# iteration 1400 / 3000: loss 2.347656
# iteration 1500 / 3000: loss 2.311365
# iteration 1600 / 3000: loss 2.200026
# iteration 1700 / 3000: loss 2.269024
# iteration 1800 / 3000: loss 2.195006
# iteration 1900 / 3000: loss 2.111798
# iteration 2000 / 3000: loss 2.121556
# iteration 2100 / 3000: loss 2.176197
# iteration 2200 / 3000: loss 2.074329
# iteration 2300 / 3000: loss 2.185313
# iteration 2400 / 3000: loss 1.958271
# iteration 2500 / 3000: loss 2.031709
# iteration 2600 / 3000: loss 2.037656
# iteration 2700 / 3000: loss 2.115969
# iteration 2800 / 3000: loss 2.033592
# iteration 2900 / 3000: loss 2.029191
# iteration 0 / 3000: loss 5.147208
# iteration 100 / 3000: loss 4.365403
# iteration 200 / 3000: loss 3.053835
# iteration 300 / 3000: loss 3.115973
# iteration 400 / 3000: loss 2.470155
# iteration 500 / 3000: loss 2.601924
# iteration 600 / 3000: loss 2.285887
# iteration 700 / 3000: loss 2.264889
# iteration 800 / 3000: loss 2.169875
# iteration 900 / 3000: loss 2.060357
# iteration 1000 / 3000: loss 2.163467
# iteration 1100 / 3000: loss 2.034415
# iteration 1200 / 3000: loss 2.047111
# iteration 1300 / 3000: loss 2.006621
# iteration 1400 / 3000: loss 1.969380
# iteration 1500 / 3000: loss 1.955569
# iteration 1600 / 3000: loss 1.901683
# iteration 1700 / 3000: loss 1.976418
# iteration 1800 / 3000: loss 1.963757
# iteration 1900 / 3000: loss 1.912319
# iteration 2000 / 3000: loss 1.930674
# iteration 2100 / 3000: loss 1.992191
# iteration 2200 / 3000: loss 1.943603
# iteration 2300 / 3000: loss 1.814853
# iteration 2400 / 3000: loss 1.886613
# iteration 2500 / 3000: loss 1.845937
# iteration 2600 / 3000: loss 1.994935
# iteration 2700 / 3000: loss 1.903757
# iteration 2800 / 3000: loss 1.980490
# iteration 2900 / 3000: loss 1.972965
# iteration 0 / 3000: loss 4.999307
# iteration 100 / 3000: loss 3.581781
# iteration 200 / 3000: loss 3.115248
# iteration 300 / 3000: loss 2.844460
# iteration 400 / 3000: loss 2.489993
# iteration 500 / 3000: loss 2.280475
# iteration 600 / 3000: loss 2.195193
# iteration 700 / 3000: loss 2.130046
# iteration 800 / 3000: loss 2.024444
# iteration 900 / 3000: loss 2.038823
# iteration 1000 / 3000: loss 2.011063
# iteration 1100 / 3000: loss 1.979021
# iteration 1200 / 3000: loss 1.923950
# iteration 1300 / 3000: loss 1.992222
# iteration 1400 / 3000: loss 1.995611
# iteration 1500 / 3000: loss 1.906861
# iteration 1600 / 3000: loss 1.911016
# iteration 1700 / 3000: loss 1.963841
# iteration 1800 / 3000: loss 1.991448
# iteration 1900 / 3000: loss 1.957108
# iteration 2000 / 3000: loss 1.990974
# iteration 2100 / 3000: loss 1.891386
# iteration 2200 / 3000: loss 1.878104
# iteration 2300 / 3000: loss 1.917890
# iteration 2400 / 3000: loss 1.912246
# iteration 2500 / 3000: loss 1.928876
# iteration 2600 / 3000: loss 1.959842
# iteration 2700 / 3000: loss 1.899664
# iteration 2800 / 3000: loss 1.996457
# iteration 2900 / 3000: loss 1.852872
# iteration 0 / 3000: loss 6.129795
# iteration 100 / 3000: loss 4.078286
# iteration 200 / 3000: loss 2.843052
# iteration 300 / 3000: loss 2.668888
# iteration 400 / 3000: loss 2.338853
# iteration 500 / 3000: loss 2.103553
# iteration 600 / 3000: loss 2.114909
# iteration 700 / 3000: loss 2.108851
# iteration 800 / 3000: loss 2.058102
# iteration 900 / 3000: loss 2.009006
# iteration 1000 / 3000: loss 1.989154
# iteration 1100 / 3000: loss 1.945353
# iteration 1200 / 3000: loss 2.024065
# iteration 1300 / 3000: loss 1.831647
# iteration 1400 / 3000: loss 1.924566
# iteration 1500 / 3000: loss 1.956353
# iteration 1600 / 3000: loss 1.919556
# iteration 1700 / 3000: loss 1.902754
# iteration 1800 / 3000: loss 1.912040
# iteration 1900 / 3000: loss 1.950386
# iteration 2000 / 3000: loss 1.968566
# iteration 2100 / 3000: loss 1.899882
# iteration 2200 / 3000: loss 1.922785
# iteration 2300 / 3000: loss 1.942832
# iteration 2400 / 3000: loss 1.940120
# iteration 2500 / 3000: loss 1.920151
# iteration 2600 / 3000: loss 1.920296
# iteration 2700 / 3000: loss 1.904379
# iteration 2800 / 3000: loss 1.955218
# iteration 2900 / 3000: loss 2.029380
# iteration 0 / 3000: loss 5.634277
# iteration 100 / 3000: loss 3.494033
# iteration 200 / 3000: loss 2.686831
# iteration 300 / 3000: loss 2.377223
# iteration 400 / 3000: loss 2.145312
# iteration 500 / 3000: loss 2.128573
# iteration 600 / 3000: loss 1.995628
# iteration 700 / 3000: loss 1.978801
# iteration 800 / 3000: loss 1.905874
# iteration 900 / 3000: loss 1.990173
# iteration 1000 / 3000: loss 1.949908
# iteration 1100 / 3000: loss 1.915665
# iteration 1200 / 3000: loss 1.939684
# iteration 1300 / 3000: loss 1.924917
# iteration 1400 / 3000: loss 1.926391
# iteration 1500 / 3000: loss 1.947919
# iteration 1600 / 3000: loss 1.907468
# iteration 1700 / 3000: loss 1.864390
# iteration 1800 / 3000: loss 1.954394
# iteration 1900 / 3000: loss 1.827596
# iteration 2000 / 3000: loss 1.942443
# iteration 2100 / 3000: loss 1.998371
# iteration 2200 / 3000: loss 1.958955
# iteration 2300 / 3000: loss 1.902748
# iteration 2400 / 3000: loss 2.008578
# iteration 2500 / 3000: loss 1.906629
# iteration 2600 / 3000: loss 1.944741
# iteration 2700 / 3000: loss 1.915800
# iteration 2800 / 3000: loss 1.996126
# iteration 2900 / 3000: loss 1.932284
# lr 2.000000e-08 reg 2.500000e+04 train accuracy: 0.294020 val accuracy: 0.300000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.352735 val accuracy: 0.364000
# lr 6.000000e-08 reg 2.500000e+04 train accuracy: 0.352000 val accuracy: 0.367000
# lr 8.000000e-08 reg 2.500000e+04 train accuracy: 0.350347 val accuracy: 0.367000
# lr 9.000000e-08 reg 2.500000e+04 train accuracy: 0.349816 val accuracy: 0.362000
# best validation accuracy achieved during cross-validation: -1.000000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
best_val = .36700
best_softmax = Softmax()
best_lr = 6.000000e-08 
best_reg =  2.500000e+04
best_softmax.train(X_train, y_train, learning_rate=best_lr, 
                   reg=best_reg, num_iters=2000, verbose=True)

y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# iteration 0 / 2000: loss 6.093740
# iteration 100 / 2000: loss 4.057399
# iteration 200 / 2000: loss 3.065680
# iteration 300 / 2000: loss 2.814055
# iteration 400 / 2000: loss 2.348571
# iteration 500 / 2000: loss 2.336272
# iteration 600 / 2000: loss 2.273755
# iteration 700 / 2000: loss 2.124976
# iteration 800 / 2000: loss 2.077322
# iteration 900 / 2000: loss 2.004254
# iteration 1000 / 2000: loss 1.958400
# iteration 1100 / 2000: loss 2.004463
# iteration 1200 / 2000: loss 1.984691
# iteration 1300 / 2000: loss 1.952567
# iteration 1400 / 2000: loss 1.949124
# iteration 1500 / 2000: loss 1.962725
# iteration 1600 / 2000: loss 1.961548
# iteration 1700 / 2000: loss 1.949347
# iteration 1800 / 2000: loss 1.934100
# iteration 1900 / 2000: loss 1.963251
# softmax on raw pixels final test set accuracy: 0.367000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
